# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'Airline-Sentiment-2-w-AA.csv', encoding='utf-8', encoding_errors='ignore')

# %%
df.tail(100)
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 14540  681679699    False   finalized                   3     2/25/15 18:43
# 14541  681679700    False   finalized                   3     2/25/15 19:20
# 14542  681679701    False   finalized                   3     2/25/15 18:47
# 14543  681679702    False   finalized                   3     2/25/15 19:30
# 14544  681679703    False   finalized                   3     2/25/15 19:02
# 14545  681679704    False   finalized                   3     2/25/15 19:01
# 14546  681679705    False   finalized                   3     2/25/15 19:11
# 14547  681679706    False   finalized                   3     2/25/15 19:02
# 14548  681679707    False   finalized                   3     2/25/15 19:21
# 14549  681679708    False   finalized                   3     2/25/15 19:42
# 14550  681679709    False   finalized                   3     2/25/15 18:55
# ...

# %%
df.shape
# Out:
# (14640, 20)

# %%
df.airline.value_counts()
# Out:
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: airline, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _unit_id                      14640 non-null  int64
#  1   _golden                       14640 non-null  bool
#  2   _unit_state                   14640 non-null  object
#  3   _trusted_judgments            14640 non-null  int64
#  4   _last_judgment_at             14584 non-null  object
#  5   airline_sentiment             14640 non-null  object
#  6   airline_sentiment:confidence  14640 non-null  float64
#  7   negativereason                9178 non-null   object
#  8   negativereason:confidence     10522 non-null  float64
#  9   airline                       14640 non-null  object
#  10  airline_sentiment_gold        40 non-null     object
#  11  name                          14640 non-null  object
# ...

# %%
sns.histplot(df.airline_sentiment);

# %%
sns.histplot(x= 'airline_sentiment', data= df, hue='airline');

# %%
plane = sns.FacetGrid(df, col='airline')
plane.map(sns.histplot, 'airline_sentiment')

# %%
plt.airline_sentiment.airline.plot(kind='pie', figsize= (12,8), fontsize= 12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tt/h9wl768d55jd_mknkzx2mnrh0000gn/T/ipykernel_1272/2381580555.py in <module>
# ----> 1 plt.airline_sentiment.airline.plot(kind='pie', figsize= (12,8), fontsize= 12)
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'airline_sentiment'

# %%
#Which airlines are doing a good job capturing customer satisfaction?
#SouthWest

# %%
#How should American airlines strategically differentiate themselves in the coming year? What opportunities do they have?
#they could better customer service to increase positive customer feedback/sentiment

# %%
#How should Southwest airlines strategically differentiate themselves in the coming year? What opportunities do they have?
# they could find ways to sway the neutral feedback to positive therefore outwaying the negative feedback
